# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline
from langchain.llms import HuggingFacePipeline
import os
 
# -------- CONFIG ---------
FAISS_PATH = "multi_format_faiss_index"  # ✅ Matches py.py output
MODEL_ID = "google/flan-t5-base"
DEVICE = "cpu"
CHUNKS_TO_USE = 4
MAX_ANSWER_LENGTH = 512
# -------------------------
 
print(f"FAISS index exists? {os.path.exists(os.path.join(FAISS_PATH, 'index.faiss'))}")
 
def load_vectorstore():
    embeddings = HuggingFaceEmbeddings(
        model_name="sentence-transformers/all-MiniLM-L6-v2",
        model_kwargs={"device": DEVICE},
        encode_kwargs={"normalize_embeddings": False}
    )
    vectorstore = FAISS.load_local(FAISS_PATH, embeddings, allow_dangerous_deserialization=True)
    return vectorstore
 
def get_top_chunks(vectorstore, query, k=CHUNKS_TO_USE):
    results = vectorstore.similarity_search(query, k=k)
    return [(doc.page_content, doc.metadata.get("source", "")) for doc in results]
 
def setup_llm():
    tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
    model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_ID)
    gen_pipeline = pipeline(
        "text2text-generation",
        model=model,
        tokenizer=tokenizer,
        device=0 if DEVICE == "cuda" else -1,
        max_length=MAX_ANSWER_LENGTH,
    )
    return HuggingFacePipeline(pipeline=gen_pipeline)
 
def build_prompt(context, question):
    prompt_template = (
        "Answer the question based on the following context.\n\n"
        "Context:\n{context}\n\n"
        "Question: {question}\n\n"
        "Answer:"
    )
    return prompt_template.format(context=context, question=question)
 
def semantic_search(query):
    vectorstore = load_vectorstore()
    llm = setup_llm()
 
    top_chunks = get_top_chunks(vectorstore, query)
    if not top_chunks:
        print("No relevant documents found.")
        return
 
    context = "\n\n".join([text for text, _ in top_chunks])
    prompt = build_prompt(context, query)
 
    answer = llm(prompt)
    if isinstance(answer, list):
        answer = answer[0].get("generated_text", "")
 
    print("\n--- Semantic Answer ---\n")
    print(answer.strip())
    print("\n--- Sources ---")
    for i, (_, src) in enumerate(top_chunks, 1):
        print(f"{i}. {src if src else 'Unknown source'}")
    print()
 
if __name__ == "__main__":
    print("Semantic Search Engine (w/ LLM Summary)")
    while True:
        query = input("\nEnter your question (or 'exit' to quit): ").strip()
        if query.lower() in {"exit", "quit"}:
            print("Exiting.")
            break
        semantic_search(query)
# Out:
# FAISS index exists? True
# Semantic Search Engine (w/ LLM Summary)
# Device set to use cpu
# Token indices sequence length is longer than the specified maximum sequence length for this model (642 > 512). Running this sequence through the model will result in indexing errors
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 81
#      79     print("Exiting.")
#      80     break
# ---> 81 semantic_search(query)
#
# Cell In[10], line 63, in semantic_search(query)
#      60 context = "\n\n".join([text for text, _ in top_chunks])
#      61 prompt = build_prompt(context, query)
# ---> 63 answer = llm(prompt)
#      64 if isinstance(answer, list):
#      65     answer = answer[0].get("generated_text", "")
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\langchain_core\_api\deprecation.py:189, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     187     warned = True
#     188     emit_warning()
# --> 189 return wrapped(*args, **kwargs)
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\langchain_core\language_models\llms.py:1313, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1306     msg = (
#    1307         "Argument `prompt` is expected to be a string. Instead found "
#    1308         f"{type(prompt)}. If you want to run the LLM on multiple prompts, use "
#    1309         "`generate` instead."
#    1310     )
#    1311     raise ValueError(msg)  # noqa: TRY004
#    1312 return (
# -> 1313     self.generate(
#    1314         [prompt],
#    1315         stop=stop,
#    1316         callbacks=callbacks,
#    1317         tags=tags,
#    1318         metadata=metadata,
#    1319         **kwargs,
#    1320     )
#    1321     .generations[0][0]
#    1322     .text
#    1323 )
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\langchain_core\language_models\llms.py:971, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     956 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     957     run_managers = [
#     958         callback_manager.on_llm_start(
#     959             self._serialized,
#    (...)    969         )
#     970     ]
# --> 971     return self._generate_helper(
#     972         prompts,
#     973         stop,
#     974         run_managers,
#     975         new_arg_supported=bool(new_arg_supported),
#     976         **kwargs,
#     977     )
#     978 if len(missing_prompts) > 0:
#     979     run_managers = [
#     980         callback_managers[idx].on_llm_start(
#     981             self._serialized,
#    (...)    988         for idx in missing_prompt_idxs
#     989     ]
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\langchain_core\language_models\llms.py:792, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     781 def _generate_helper(
#     782     self,
#     783     prompts: list[str],
#    (...)    788     **kwargs: Any,
#     789 ) -> LLMResult:
#     790     try:
#     791         output = (
# --> 792             self._generate(
#     793                 prompts,
#     794                 stop=stop,
#     795                 # TODO: support multiple run managers
#     796                 run_manager=run_managers[0] if run_managers else None,
#     797                 **kwargs,
#     798             )
#     799             if new_arg_supported
#     800             else self._generate(prompts, stop=stop)
#     801         )
#     802     except BaseException as e:
#     803         for run_manager in run_managers:
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\langchain_community\llms\huggingface_pipeline.py:285, in HuggingFacePipeline._generate(self, prompts, stop, run_manager, **kwargs)
#     282 batch_prompts = prompts[i : i + self.batch_size]
#     284 # Process batch of prompts
# --> 285 responses = self.pipeline(
#     286     batch_prompts,
#     287     **pipeline_kwargs,
#     288 )
#     290 # Process each response in the batch
#     291 for j, response in enumerate(responses):
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\transformers\pipelines\text2text_generation.py:187, in Text2TextGenerationPipeline.__call__(self, *args, **kwargs)
#     158 def __call__(self, *args: Union[str, list[str]], **kwargs: Any) -> list[dict[str, str]]:
#     159     r"""
#     160     Generate the output text(s) using text(s) given as inputs.
#     161
#    (...)    184           ids of the generated text.
#     185     """
# --> 187     result = super().__call__(*args, **kwargs)
#     188     if (
#     189         isinstance(args[0], list)
#     190         and all(isinstance(el, str) for el in args[0])
#     191         and all(len(res) == 1 for res in result)
#     192     ):
#     193         return [res[0] for res in result]
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\transformers\pipelines\base.py:1445, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1441 if can_use_iterator:
#    1442     final_iterator = self.get_iterator(
#    1443         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1444     )
# -> 1445     outputs = list(final_iterator)
#    1446     return outputs
#    1447 else:
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\transformers\pipelines\pt_utils.py:124, in PipelineIterator.__next__(self)
#     121     return self.loader_batch_item()
#     123 # We're out of items within a batch
# --> 124 item = next(self.iterator)
#     125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\transformers\pipelines\pt_utils.py:125, in PipelineIterator.__next__(self)
#     123 # We're out of items within a batch
#     124 item = next(self.iterator)
# --> 125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#     127 if self.loader_batch_size is not None:
#     128     # Try to infer the size of the batch
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\transformers\pipelines\base.py:1371, in Pipeline.forward(self, model_inputs, **forward_params)
#    1369     with inference_context():
#    1370         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1371         model_outputs = self._forward(model_inputs, **forward_params)
#    1372         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1373 else:
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\transformers\pipelines\text2text_generation.py:216, in Text2TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     213 if "generation_config" not in generate_kwargs:
#     214     generate_kwargs["generation_config"] = self.generation_config
# --> 216 output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     217 out_b = output_ids.shape[0]
#     218 if self.framework == "pt":
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\transformers\generation\utils.py:2644, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2637     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2638         input_ids=input_ids,
#    2639         expand_size=generation_config.num_beams,
#    2640         is_encoder_decoder=self.config.is_encoder_decoder,
#    2641         **model_kwargs,
#    2642     )
#    2643     # 12. run beam sample
# -> 2644     result = self._beam_search(
#    2645         input_ids,
#    2646         logits_processor=prepared_logits_processor,
#    2647         stopping_criteria=prepared_stopping_criteria,
#    2648         generation_config=generation_config,
#    2649         synced_gpus=synced_gpus,
#    2650         **model_kwargs,
#    2651     )
#    2653 elif generation_mode == GenerationMode.GROUP_BEAM_SEARCH:
#    2654     logger.warning_once(
#    2655         "Group Beam Search is scheduled to be moved to a `custom_generate` repository in v4.55.0. "
#    2656         "To prevent loss of backward compatibility, add `trust_remote_code=True` to your `generate` call."
#    2657     )
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\transformers\generation\utils.py:4079, in GenerationMixin._beam_search(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    4076 model_inputs.update({"output_attentions": output_attentions} if output_attentions else {})
#    4077 model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
# -> 4079 model_outputs = self(**model_inputs, return_dict=True)
#    4081 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    4082 model_kwargs = self._update_model_kwargs_for_generation(
#    4083     model_outputs,
#    4084     model_kwargs,
#    4085     is_encoder_decoder=self.config.is_encoder_decoder,
#    4086 )
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:1792, in T5ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1789         decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_device)
#    1791 # Decode
# -> 1792 decoder_outputs = self.decoder(
#    1793     input_ids=decoder_input_ids,
#    1794     attention_mask=decoder_attention_mask,
#    1795     inputs_embeds=decoder_inputs_embeds,
#    1796     past_key_values=past_key_values,
#    1797     encoder_hidden_states=hidden_states,
#    1798     encoder_attention_mask=attention_mask,
#    1799     head_mask=decoder_head_mask,
#    1800     cross_attn_head_mask=cross_attn_head_mask,
#    1801     use_cache=use_cache,
#    1802     output_attentions=output_attentions,
#    1803     output_hidden_states=output_hidden_states,
#    1804     return_dict=return_dict,
#    1805     cache_position=cache_position,
#    1806 )
#    1808 sequence_output = decoder_outputs[0]
#    1810 # Set device for model parallelism
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:1105, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1102 if output_hidden_states:
#    1103     all_hidden_states = all_hidden_states + (hidden_states,)
# -> 1105 layer_outputs = layer_module(
#    1106     hidden_states,
#    1107     causal_mask,
#    1108     position_bias,
#    1109     encoder_hidden_states,
#    1110     encoder_extended_attention_mask,
#    1111     encoder_decoder_position_bias,  # as a positional argument for gradient checkpointing
#    1112     layer_head_mask=layer_head_mask,
#    1113     cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1114     past_key_value=past_key_values,
#    1115     use_cache=use_cache,
#    1116     output_attentions=output_attentions,
#    1117     return_dict=return_dict,
#    1118     cache_position=cache_position,
#    1119 )
#    1121 # layer_outputs is a tuple with:
#    1122 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1123 if use_cache is False:
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\transformers\modeling_layers.py:83, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      80         logger.warning(message)
#      82     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 83 return super().__call__(*args, **kwargs)
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:702, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict, cache_position)
#     700 do_cross_attention = self.is_decoder and encoder_hidden_states is not None
#     701 if do_cross_attention:
# --> 702     cross_attention_outputs = self.layer[1](
#     703         hidden_states,
#     704         key_value_states=encoder_hidden_states,
#     705         attention_mask=encoder_attention_mask,
#     706         position_bias=encoder_decoder_position_bias,
#     707         layer_head_mask=cross_attn_layer_head_mask,
#     708         past_key_value=past_key_value,
#     709         query_length=cache_position[-1] + 1,
#     710         use_cache=use_cache,
#     711         output_attentions=output_attentions,
#     712     )
#     713     hidden_states, past_key_value = cross_attention_outputs[:2]
#     715     # clamp inf values to enable fp16 training
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:632, in T5LayerCrossAttention.forward(self, hidden_states, key_value_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, query_length, output_attentions, cache_position)
#     618 def forward(
#     619     self,
#     620     hidden_states,
#    (...)    629     cache_position=None,
#     630 ):
#     631     normed_hidden_states = self.layer_norm(hidden_states)
# --> 632     attention_output = self.EncDecAttention(
#     633         normed_hidden_states,
#     634         mask=attention_mask,
#     635         key_value_states=key_value_states,
#     636         position_bias=position_bias,
#     637         layer_head_mask=layer_head_mask,
#     638         past_key_value=past_key_value,
#     639         use_cache=use_cache,
#     640         query_length=query_length,
#     641         output_attentions=output_attentions,
#     642         cache_position=cache_position,
#     643     )
#     644     layer_output = hidden_states + self.dropout(attention_output[0])
#     645     outputs = (layer_output,) + attention_output[1:]  # add attentions if we output them
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\muskan.verma\AppData\Local\miniconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:523, in T5Attention.forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions, cache_position)
#     520             past_key_value.is_updated[self.layer_idx] = True
#     522 # compute scores, equivalent of torch.einsum("bnqd,bnkd->bnqk", query_states, key_states), compatible with onnx op>9
# --> 523 scores = torch.matmul(query_states, key_states.transpose(3, 2))
#     525 if position_bias is None:
#     526     key_length = key_states.shape[-2]
#
# KeyboardInterrupt:
